# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiyeon1104/ai/blob/main/%EC%95%88%EB%A9%B4%EC%9D%B8%EC%8B%9D(API).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ID : IMYhK4b7_zewYyfouTMG
# PW : ZzHxbnbxZl

# %%
import os         # 운영체제 접근
import sys        # 시스템 접근
import requests # 웹 접근

client_id = "IMYhK4b7_zewYyfouTMG"
client_secret = "ZzHxbnbxZl"

url = "https://openapi.naver.com/v1/vision/face"    #얼굴감지
#url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식


files = {'image': open('image2.jpg', 'rb')} # 사진 파일이름

headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":565,"height":337},"faceCount":5},"faces":[{"roi":{"x":359,"y":68,"width":43,"height":43},"landmark":{"leftEye":{"x":369,"y":75},"rightEye":{"x":390,"y":78},"nose":{"x":376,"y":89},"leftMouth":{"x":366,"y":97},"rightMouth":{"x":386,"y":100}},"gender":{"value":"male","confidence":0.99867},"age":{"value":"37~41","confidence":0.145799},"emotion":{"value":"smile","confidence":0.99522},"pose":{"value":"frontal_face","confidence":0.999489}},{"roi":{"x":164,"y":91,"width":43,"height":43},"landmark":{"leftEye":{"x":181,"y":98},"rightEye":{"x":201,"y":101},"nose":{"x":192,"y":111},"leftMouth":{"x":178,"y":117},"rightMouth":{"x":196,"y":122}},"gender":{"value":"female","confidence":0.999884},"age":{"value":"31~35","confidence":0.457837},"emotion":{"value":"smile","confidence":0.99328},"pose":{"value":"frontal_face","confidence":0.946745}},{"roi":{"x":291,"y":104,"width":43,"height":43},"landmark":null,"gender":{"value":"male","confidence":0.808793},"age":{"value":"18~22","confidence":6.81145E-4},"emotion":{"value":"neutral","confidence":0.740991},"pose":{"value":"part_face","confidence":0.544328}},{"roi":{"x":221,"y":134,"width":34,"height":34},"landmark":{"leftEye":{"x":230,"y":143},"rightEye":{"x":244,"y":144},"nose":{"x":235,"y":150},"leftMouth":{"x":230,"y":158},"rightMouth":{"x":242,"y":159}},"gender":{"value":"male","confidence":0.754489},"age":{"value":"0~3","confidence":1.0},"emotion":{"value":"smile","confidence":0.593257},"pose":{"value":"frontal_face","confidence":0.97947}},{"roi":{"x":226,"y":233,"width":40,"height":40},"landmark":null,"gender":{"value":"female","confidence":0.998447},"age":{"value":"52~56","confidence":0.0335061},"emotion":{"value":"laugh","confidence":0.459469},"pose":{"value":"false_face","confidence":0.941793}}]}

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 565, 'height': 337}, 'faceCount': 5}, 'faces': [{'roi': {'x': 359, 'y': 68, 'width': 43, 'height': 43}, 'landmark': {'leftEye': {'x': 369, 'y': 75}, 'rightEye': {'x': 390, 'y': 78}, 'nose': {'x': 376, 'y': 89}, 'leftMouth': {'x': 366, 'y': 97}, 'rightMouth': {'x': 386, 'y': 100}}, 'gender': {'value': 'male', 'confidence': 0.99867}, 'age': {'value': '37~41', 'confidence': 0.145799}, 'emotion': {'value': 'smile', 'confidence': 0.99522}, 'pose': {'value': 'frontal_face', 'confidence': 0.999489}}, {'roi': {'x': 164, 'y': 91, 'width': 43, 'height': 43}, 'landmark': {'leftEye': {'x': 181, 'y': 98}, 'rightEye': {'x': 201, 'y': 101}, 'nose': {'x': 192, 'y': 111}, 'leftMouth': {'x': 178, 'y': 117}, 'rightMouth': {'x': 196, 'y': 122}}, 'gender': {'value': 'female', 'confidence': 0.999884}, 'age': {'value': '31~35', 'confidence': 0.457837}, 'emotion': {'value': 'smile', 'confidence': 0.99328}, 'pose': {'value': 'frontal_face', 'confidence': 0.946745}}, {'roi': {'x': 291, 'y': 104, 'width': 43, 'height': 43}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.808793}, 'age': {'value': '18~22', 'confidence': 0.000681145}, 'emotion': {'value': 'neutral', 'confidence': 0.740991}, 'pose': {'value': 'part_face', 'confidence': 0.544328}}, {'roi': {'x': 221, 'y': 134, 'width': 34, 'height': 34}, 'landmark': {'leftEye': {'x': 230, 'y': 143}, 'rightEye': {'x': 244, 'y': 144}, 'nose': {'x': 235, 'y': 150}, 'leftMouth': {'x': 230, 'y': 158}, 'rightMouth': {'x': 242, 'y': 159}}, 'gender': {'value': 'male', 'confidence': 0.754489}, 'age': {'value': '0~3', 'confidence': 1.0}, 'emotion': {'value': 'smile', 'confidence': 0.593257}, 'pose': {'value': 'frontal_face', 'confidence': 0.97947}}, {'roi': {'x': 226, 'y': 233, 'width': 40, 'height': 40}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.998447}, 'age': {'value': '52~56', 'confidence': 0.0335061}, 'emotion': {'value': 'laugh', 'confidence': 0.459469}, 'pose': {'value': 'false_face', 'confidence': 0.941793}}]}

# %%
print(json.dumps(parsed, indent= 4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 565,
#             "height": 337
#         },
#         "faceCount": 5
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 359,
#                 "y": 68,
#                 "width": 43,
#                 "height": 43
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 369,
#                     "y": 75
#                 },
#                 "rightEye": {
#                     "x": 390,
#                     "y": 78
#                 },
#                 "nose": {
#                     "x": 376,
#                     "y": 89
#                 },
#                 "leftMouth": {
#                     "x": 366,
#                     "y": 97
#                 },
#                 "rightMouth": {
#                     "x": 386,
#                     "y": 100
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.99867
#             },
#             "age": {
#                 "value": "37~41",
#                 "confidence": 0.145799
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.99522
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999489
#             }
#         },
#         {
#             "roi": {
#                 "x": 164,
#                 "y": 91,
#                 "width": 43,
#                 "height": 43
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 181,
#                     "y": 98
#                 },
#                 "rightEye": {
#                     "x": 201,
#                     "y": 101
#                 },
#                 "nose": {
#                     "x": 192,
#                     "y": 111
#                 },
#                 "leftMouth": {
#                     "x": 178,
#                     "y": 117
#                 },
#                 "rightMouth": {
#                     "x": 196,
#                     "y": 122
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999884
#             },
#             "age": {
#                 "value": "31~35",
#                 "confidence": 0.457837
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.99328
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.946745
#             }
#         },
#         {
#             "roi": {
#                 "x": 291,
#                 "y": 104,
#                 "width": 43,
#                 "height": 43
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.808793
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.000681145
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.740991
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.544328
#             }
#         },
#         {
#             "roi": {
#                 "x": 221,
#                 "y": 134,
#                 "width": 34,
#                 "height": 34
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 230,
#                     "y": 143
#                 },
#                 "rightEye": {
#                     "x": 244,
#                     "y": 144
#                 },
#                 "nose": {
#                     "x": 235,
#                     "y": 150
#                 },
#                 "leftMouth": {
#                     "x": 230,
#                     "y": 158
#                 },
#                 "rightMouth": {
#                     "x": 242,
#                     "y": 159
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.754489
#             },
#             "age": {
#                 "value": "0~3",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.593257
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.97947
#             }
#         },
#         {
#             "roi": {
#                 "x": 226,
#                 "y": 233,
#                 "width": 40,
#                 "height": 40
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.998447
#             },
#             "age": {
#                 "value": "52~56",
#                 "confidence": 0.0335061
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.459469
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.941793
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 565, 'height': 337}, 'faceCount': 5}

# %%
print(parsed['faces'])
# Out:
# [{'roi': {'x': 359, 'y': 68, 'width': 43, 'height': 43}, 'landmark': {'leftEye': {'x': 369, 'y': 75}, 'rightEye': {'x': 390, 'y': 78}, 'nose': {'x': 376, 'y': 89}, 'leftMouth': {'x': 366, 'y': 97}, 'rightMouth': {'x': 386, 'y': 100}}, 'gender': {'value': 'male', 'confidence': 0.99867}, 'age': {'value': '37~41', 'confidence': 0.145799}, 'emotion': {'value': 'smile', 'confidence': 0.99522}, 'pose': {'value': 'frontal_face', 'confidence': 0.999489}}, {'roi': {'x': 164, 'y': 91, 'width': 43, 'height': 43}, 'landmark': {'leftEye': {'x': 181, 'y': 98}, 'rightEye': {'x': 201, 'y': 101}, 'nose': {'x': 192, 'y': 111}, 'leftMouth': {'x': 178, 'y': 117}, 'rightMouth': {'x': 196, 'y': 122}}, 'gender': {'value': 'female', 'confidence': 0.999884}, 'age': {'value': '31~35', 'confidence': 0.457837}, 'emotion': {'value': 'smile', 'confidence': 0.99328}, 'pose': {'value': 'frontal_face', 'confidence': 0.946745}}, {'roi': {'x': 291, 'y': 104, 'width': 43, 'height': 43}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.808793}, 'age': {'value': '18~22', 'confidence': 0.000681145}, 'emotion': {'value': 'neutral', 'confidence': 0.740991}, 'pose': {'value': 'part_face', 'confidence': 0.544328}}, {'roi': {'x': 221, 'y': 134, 'width': 34, 'height': 34}, 'landmark': {'leftEye': {'x': 230, 'y': 143}, 'rightEye': {'x': 244, 'y': 144}, 'nose': {'x': 235, 'y': 150}, 'leftMouth': {'x': 230, 'y': 158}, 'rightMouth': {'x': 242, 'y': 159}}, 'gender': {'value': 'male', 'confidence': 0.754489}, 'age': {'value': '0~3', 'confidence': 1.0}, 'emotion': {'value': 'smile', 'confidence': 0.593257}, 'pose': {'value': 'frontal_face', 'confidence': 0.97947}}, {'roi': {'x': 226, 'y': 233, 'width': 40, 'height': 40}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.998447}, 'age': {'value': '52~56', 'confidence': 0.0335061}, 'emotion': {'value': 'laugh', 'confidence': 0.459469}, 'pose': {'value': 'false_face', 'confidence': 0.941793}}]

# %%
parsed['faces'][4]
# Out:
# {'age': {'confidence': 0.0335061, 'value': '52~56'},
#  'emotion': {'confidence': 0.459469, 'value': 'laugh'},
#  'gender': {'confidence': 0.998447, 'value': 'female'},
#  'landmark': None,
#  'pose': {'confidence': 0.941793, 'value': 'false_face'},
#  'roi': {'height': 40, 'width': 40, 'x': 226, 'y': 233}}

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('image2.jpg')     # 사진 읽어오기
fig, ax = plt.subplots()                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 


x,y,w,h = parsed['faces'][1]['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
age, age_confidence = parsed['faces'][1]['age'].values()
gender, gender_confidence = parsed['faces'][1]['gender'].values()
  
anno = gender + ',' + age
re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보
plt.text(x,y,anno,color = 'blue')
ax.add_patch(re_face)                         # 기본 사진에 사각형 정보를 올려 수정

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('image2.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 

for each in parsed['faces']:
  x,y,w,h = each['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
  age, age_confidence = each['age'].values()
  gender, gender_confidence = each['gender'].values()
  
  anno = gender + ',' + age
  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보
  plt.text(x,y+h+20,anno,color='blue')
  ax.add_patch(re_face)

# %%
# 각 사람의 얼굴 아래 또는 오른쪽에 성별, 나이를 표시
