# %%
from selenium import webdriver # 파이썬으로 브라우저 컨트롤 모듈
from bs4 import BeautifulSoup as bs # 크롤링한 데이터 정제
import pandas as pd # 데이터 분석 모듈

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.starbucks.co.kr/store/store_map.do')
# Out:
# C:\Users\rlawl\AppData\Local\Temp/ipykernel_8276/2198966681.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
area_btn = '#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a'
driver.find_element_by_css_selector(area_btn).click()
# Out:
# C:\Users\rlawl\AppData\Local\Temp/ipykernel_8276/2162603177.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(area_btn).click()

# %%
seoul_btn = '#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a'
driver.find_element_by_css_selector(seoul_btn).click()
# Out:
# C:\Users\rlawl\AppData\Local\Temp/ipykernel_8276/3501212899.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(seoul_btn).click()

# %%
all_btn = '#mCSB_2_container > ul > li:nth-child(1) > a'
driver.find_element_by_css_selector(all_btn).click()
# Out:
# C:\Users\rlawl\AppData\Local\Temp/ipykernel_8276/4097843641.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(whole_btn).click()

# %%
html = driver.page_source  # 전체 페이지 소스 읽어오기
soup = bs(html) # bs로 데이터 정제하여 분석 준비

# %%
len(soup.select('li.quickResultLstCon'))
# Out:
# 589

# %%
soup.select('li.quickResultLstCon')[0]
# Out:
# <li class="quickResultLstCon" data-code="3365" data-hlytag="null" data-index="0" data-lat="37.559593" data-long="127.006142" data-name="동대입구역" data-storecd="1140" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="동대입구역" data-store="1140" data-yn="N">동대입구역  </strong> <p class="result_details">서울특별시 중구 장충단로 166 (장충동1가)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
branchs = soup.select('ul.quickSearchResultBoxSidoGugun > li.quickResultLstCon')

print(branchs)
# Out:
# [<li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>, <li class="quickResultLstCon" data-code="3672" data-hlytag="null" data-index="1" data-lat="37.510178" data-long="127.022223" data-name="논현역사거리" data-storecd="1434" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="논현역사거리" data-store="1434" data-yn="N">논현역사거리  </strong> <p class="result_details">서울특별시 강남구 강남대로 538 (논현동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>, <li class="quickResultLstCon" data-code="3858" data-hlytag="null" data-index="2" data-lat="37.514132" data-long="127.020563" data-name="신사역성일빌딩" data-storecd="1595" style="backg
# ...

# %%
star = branchs[0]
star
#name =             # 지점명 
#lat =              # 위도
#lng =              # 경도
#addr =             # 주소
#tel =              # 전화번호
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>
